# %%
# 3개의 숫자 중 최대값 구하기

a, b, c = input("세 개의 숫자를 입력하세요").split()
print(a, b, c)
# Out:
# 세 개의 숫자를 입력하세요 10 23 14
# 10 23 14

# %%
# 3개의 숫자 중 최대값 구하기

a, b, c = input("세 개의 숫자를 입력하세요").split()
print(a, b, c)
print(type(a))
# Out:
# 세 개의 숫자를 입력하세요 10 23 14
# 10 23 14
# <class 'str'>

# %%
# 3개의 숫자 중 최대값 구하기

a, b, c = input("세 개의 숫자를 입력하세요").split()
a = int(a)
b = int(b)
c = int(c)
print(type(a))
# Out:
# 세 개의 숫자를 입력하세요 10 23 14
# <class 'int'>

# %%
# 3개의 숫자 중 최대값 구하기 
# (control + / = 한번에 바꾸기)

# a, b, c = input("세 개의 숫자를 입력하세요").split()
# a = int(a)
# b = int(b)
# c = int(c)

# a, b, c = map(int, input("세 개의 숫자를 입력하세요").split()) <- 이거 외워서 쓰기

a, b, c = map(int, input("세 개의 숫자를 입력하세요").split())
print(type(a))
# Out:
# 세 개의 숫자를 입력하세요 10 23 14
# <class 'int'>

# %%
# 3개의 숫자 중 최대값 구하기 
# (control + / = 한번에 바꾸기)

# a, b, c = input("세 개의 숫자를 입력하세요").split()
# a = int(a)
# b = int(b)
# c = int(c)
# print(type(a))

a, b, c = map(int, input("세 개의 숫자를 입력하세요").split())
print(type(a))

max = a
if max < b: max = b
if max < c: max = c
print(f'가장 큰 수는 {max}입니다.')
# Out:
# 세 개의 숫자를 입력하세요 10 23 14
# <class 'int'>
# 가장 큰 수는 23입니다.

# %%
# a > b가 되도록 swap

a, b = map(int, input('두 수를 입력하세요:').split())

if a < b:
    a, b = b, a

print('>>', a, b)
# Out:
# 두 수를 입력하세요: 15 34
# >> 34 15

# %%
# a > b가 되도록 swap

a, b = map(int, input('두 수를 입력하세요:').split())
# print('>>', a, b)

if a < b:
    a, b = b, a

print('>>', a, b)
# Out:
# 두 수를 입력하세요: 15 34
# >> 34 15

# %%
# 홀수, 짝수 판단
num = int(input())
if num % 2 ==0:
    print("짝수입니다.")
else:
    print("홀수입니다.")
# Out:
#  10
# 짝수입니다.

# %%
age1 = int(input('첫번째 사람의 나이:'))
age2 = int(input('두번째 사람의 나이:'))

if age1 > age2:
    print('>>나이 차이 :', age1 - age2)
else:
    print('>>나이 차이 :', age2 - age1)
# Out:
# 첫번째 사람의 나이: 45
# 두번째 사람의 나이: 23
# >>나이 차이 : 22

# %%
age1 = int(input('첫번째 사람의 나이:'))
age2 = int(input('두번째 사람의 나이:'))

if age1 > age2:
    diff = age1 - age2
else:
    diff = age2 - age1

print('>> 나이 차이 :', diff)
# Out:
# 첫번째 사람의 나이: 17
# 두번째 사람의 나이: 43
# >> 나이 차이 : 26

# %%
# 입력된 숫자가 음수, 0, 양수인지 출력
num = int(input('숫자를 입력하세요 :'))
if num > 0:
    print('>> 양수입니다.')
elif num == 0:
    print('>> 0입니다.')
else:
    print('>> 음수입니다.')
# Out:
# 숫자를 입력하세요 : -43
# >> 음수입니다.

# %%
# 입력된 점수에 따라 등급을 출력
score = int(input('점수를 입력하세요 :'))

if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
elif score < 60:
    grade = 'F'


print(f'>> 등급은 {grade}입니다.')
# Out:
# 점수를 입력하세요 : 59
# >> 등급은 F입니다.

# %%
#놀이공원 기본 입장료가 5,000원이고 나이에 따른 할인율이 다음과 같은 경우, 나이를 입력받아 입장료를 구하기
age = int(input('나이를 입력하세요 :'))
price = 5000

if age < 8:
    price = 5000 * (1-0.3)
elif 8 <= age < 60:
    pirce = 5000
elif age >= 60:
    price = 5000 * (1-0.2)
    

print(f'>> 입장료는 {price}입니다.')
# Out:
# 나이를 입력하세요 : 67
# >> 입장료는 4000.0입니다.

# %%
# 숫자를 입력 받아서 양수인 경우에만 짝수인지 홀수인지 출력한다. 양수가 아니면, 양수가 아니라고 출력

num = int(input('숫자를 입력하세요:'))

if num > 0:
    if num % 2 == 0:
        print('짝수입니다.')
    else:
        print('홀수입니다.')
else:
    print('양수가 아닙니다.')
# Out:
# 숫자를 입력하세요: 1
# 홀수입니다.

# %%
# BOJ A+B 1000
a, b = map(int, input().split())
print(a + b)
# Out:
#  1 2
# 3

# %%
#  BOJ 초코바 27959
N, M = map(int, input().split())

if N * 100 >= M:
    print('Yes')
else:
    print('No')
# Out:
#  7 785
# No

# %%
# BOJ A-B 1001
a, b = map(int, input().split())
print(a - b)
# Out:
#  3 2
# 1

# %%
# BOJ A*B 10998
a, b = map(int, input().split())
print(a * b)
# Out:
#  1 2
# 2

# %%
# BOJ A/B 1008
a, b = map(int, input().split())
print(a / b)
# Out:
#  1 3
# 0.3333333333333333

# %%
# BOJ 사칙연산 10869
a, b = map(int, input().split())
print(a + b)
print(a - b)
print(a * b)
print(a // b)
print(a % b)
# Out:
#  7 3
# 10
# 4
# 21
# 2
# 1

# %%
# BOJ 나머지 10430
a, b, c = map(int, input().split())
print((a + b) % c)
print(((a % c) + (b % c)) % c)
print((a * b) % c)
print(((a % c) * (b % c)) % c)
# Out:
#  5 8 4
# 1
# 1
# 0
# 0

# %%
# BOJ 엄청난 부자2 1271
n, m = map(int, input().split())
print(n // m)
print(n % m)
# Out:
#  1000 100
# 10
# 0

# %%
n, m, k = map(int, input().split())

print(k // m)
print(k % m)
# Out:
#  6 4 14
# 3
# 2
